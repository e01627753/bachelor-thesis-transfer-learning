# %% [markdown]
# ## Bachelor Thesis
#
# ### Approaches:

# %%
from Main import *

# %%
plt_results("results/result_tree08_ws.pkl")
# Out:
# Validation Scores : [0.9667888  0.96645998 0.96725855 0.96727421 0.9673525 ]
# Accuracy : 0.9689343738647894
